# %%
dbutils.fs.ls("/mnt/processed/Ads_General_Por_Dia/anuncios_insights_general_por_dia_limpiado.csv")
# Out:
# [FileInfo(path='dbfs:/mnt/processed/Ads_General_Por_Dia/anuncios_insights_general_por_dia_limpiado.csv', name='anuncios_insights_general_por_dia_limpiado.csv', size=65270, modificationTime=1731344906000)]

# %%
# Crear la base de datos en caso de que no exista
spark.sql("CREATE DATABASE IF NOT EXISTS db_pecsa_ads")

# Eliminar la tabla si ya existe
spark.sql("DROP TABLE IF EXISTS db_pecsa_ads.meta_ads")

# Leer el archivo CSV
df = spark.read.csv("/mnt/processed/Ads_General_Por_Dia/anuncios_insights_general_por_dia_limpiado.csv", header=True, inferSchema=True)

# Escribir el DataFrame como una nueva tabla
df.write.mode("overwrite").saveAsTable("db_pecsa_ads.meta_ads")

# Verificar que la tabla se haya creado
spark.sql("SHOW TABLES IN db_pecsa_ads").show()
# Out:
# +------------+---------+-----------+
# |    database|tableName|isTemporary|
# +------------+---------+-----------+
# |db_pecsa_ads| meta_ads|      false|
# +------------+---------+-----------+

# %%
# %sql
SELECT * FROM db_pecsa_ads.meta_ads
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_anuncio</th><th>nombre_anuncio</th><th>adset_name</th><th>nombre_campana</th><th>fecha_inicio</th><th>fecha_finalizacion</th><th>personas_alcanzadas</th><th>veces_mostrado</th><th>promedio_frecuencia</th><th>gasto</th><th>clicks_en_anuncio</th><th>click_enlace_trafico</th><th>conversion_mercado</th><th>costo_por_click_anuncio</th><th>costo_por_resultado</th><th>costo_por_mil_impresiones</th><th>calidad_mercado</th><th>tipo_compra</th><th>interaccion_post</th><th>interaccion_page</th><th>vistas_video</th><th>reacciones_post</th><th>click_link</th><th>conversion_boton_msj</th><th>conversion_primer_respuesta</th><th>comentarios</th><th>3er_msj_cliente</th><th>2do_msj_cliente</th><th>like</th><th>msj_iniciado_por_cliente_ultimos_7Dias</th><th>vistas_mensaje_bienvenida</th><th>msjs_respondidos_por_pecsa_antes_de_7Dias</th><th>contenido_publicado</th><th>contenido_guardado</th></tr></thead><tbody><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-11-06</td><td>2024-11-06</td><td>2000</td><td>2756</td><td>1.378</td><td>106.27</td><td>81</td><td>9.0</td><td>desconocido</td><td>1.311975</td><td>53.135</td><td>38.559507</td><td>desconocido</td><td>subasta</td><td>382.0</td><td>382.0</td><td>371.0</td><td>1.0</td><td>9.0</td><td>7.0</td><td>null</td><td>1.0</td><td>3.0</td><td>3.0</td><td>null</td><td>3.0</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-11-07</td><td>2024-11-07</td><td>2290</td><td>3487</td><td>1.522707</td><td>155.1</td><td>76</td><td>5.0</td><td>desconocido</td><td>2.040789</td><td>67.729258</td><td>44.479495</td><td>desconocido</td><td>subasta</td><td>428.0</td><td>428.0</td><td>421.0</td><td>1.0</td><td>5.0</td><td>2.0</td><td>1.0</td><td>null</td><td>1.0</td><td>2.0</td><td>null</td><td>2.0</td><td>null</td><td>null</td><td>null</td><td>1.0</td></tr><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-11-08</td><td>2024-11-08</td><td>383</td><td>453</td><td>1.182768</td><td>24.78</td><td>8</td><td>1.0</td><td>desconocido</td><td>3.0975</td><td>64.699739</td><td>54.701987</td><td>desconocido</td><td>subasta</td><td>58.0</td><td>58.0</td><td>56.0</td><td>1.0</td><td>1.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-11-09</td><td>2024-11-09</td><td>320</td><td>400</td><td>1.25</td><td>19.72</td><td>17</td><td>2.0</td><td>desconocido</td><td>1.16</td><td>61.625</td><td>49.3</td><td>desconocido</td><td>subasta</td><td>76.0</td><td>76.0</td><td>73.0</td><td>1.0</td><td>2.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-11-10</td><td>2024-11-10</td><td>1018</td><td>1432</td><td>1.40668</td><td>53.45</td><td>30</td><td>3.0</td><td>desconocido</td><td>1.781667</td><td>52.504912</td><td>37.325419</td><td>desconocido</td><td>subasta</td><td>190.0</td><td>190.0</td><td>186.0</td><td>1.0</td><td>3.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236578610669</td><td>Test_AdVideo_PreNavidad</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-11-06</td ...
