# %%
# %pip install requests
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: requests in /databricks/python3/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.10/site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests) (2022.12.7)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
dbutils.library.restartPython()

# %%
dbutils.fs.ls("/mnt/processed")
# Out:
# [FileInfo(path='dbfs:/mnt/processed/Ads_General_Por_Dia/', name='Ads_General_Por_Dia/', size=0, modificationTime=1731353128000),
#  FileInfo(path='dbfs:/mnt/processed/Ads_General_Por_Hora/', name='Ads_General_Por_Hora/', size=0, modificationTime=1731361379000),
#  FileInfo(path='dbfs:/mnt/processed/Ads_General_Total/', name='Ads_General_Total/', size=0, modificationTime=1731361391000)]

# %%
import pandas as pd

# Ensure the file path includes the correct extension, such as '.csv'
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ad_id</th><th>ad_name</th><th>adset_name</th><th>campaign_name</th><th>date_start</th><th>date_stop</th><th>reach</th><th>impressions</th><th>frequency</th><th>spend</th><th>clicks</th><th>conversion_rate_ranking</th><th>cpc</th><th>cpp</th><th>cpm</th><th>actions</th><th>quality_ranking</th><th>buying_type</th><th>inline_link_clicks</th></tr></thead><tbody><tr><td>120211236488430669</td><td>Test_AdVideo_LosArtistas</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>436</td><td>622</td><td>1.426606</td><td>21.35</td><td>11</td><td>UNKNOWN</td><td>1.940909</td><td>48.96789</td><td>34.324759</td><td>[{'action_type': 'post_engagement', 'value': '106'}, {'action_type': 'page_engagement', 'value': '106'}, {'action_type': 'video_view', 'value': '105'}, {'action_type': 'post_reaction', 'value': '1'}]</td><td>UNKNOWN</td><td>AUCTION</td><td>null</td></tr><tr><td>120211236578610669</td><td>Test_AdVideo_PreNavidad</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>205</td><td>347</td><td>1.692683</td><td>19.23</td><td>12</td><td>UNKNOWN</td><td>1.6025</td><td>93.804878</td><td>55.417867</td><td>[{'action_type': 'post_engagement', 'value': '48'}, {'action_type': 'page_engagement', 'value': '48'}, {'action_type': 'video_view', 'value': '48'}]</td><td>UNKNOWN</td><td>AUCTION</td><td>null</td></tr><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>4382</td><td>8530</td><td>1.9466</td><td>359.37</td><td>212</td><td>UNKNOWN</td><td>1.695142</td><td>82.010497</td><td>42.130129</td><td>[{'action_type': 'onsite_conversion.total_messaging_connection', 'value': '9'}, {'action_type': 'onsite_conversion.messaging_first_reply', 'value': '1'}, {'action_type': 'post_engagement', 'value': '1134'}, {'action_type': 'onsite_conversion.post_save', 'value': '1'}, {'action_type': 'comment', 'value': '1'}, {'action_type': 'page_engagement', 'value': '1134'}, {'action_type': 'onsite_conversion.messaging_user_depth_3_message_send', 'value': '4'}, {'action_type': 'onsite_conversion.messaging_user_depth_2_message_send', 'value': '5'}, {'action_type': 'onsite_conversion.messaging_conversation_started_7d', 'value': '5'}, {'action_type': 'video_view', 'value': '1107'}, {'action_type': 'post_reaction', 'value': '5'}, {'action_type': 'link_click', 'value': '20'}]</td><td>UNKNOWN</td><td>AUCTION</td><td>20.0</td></tr><tr><td>120211236488480669</td><td>Test_AdVideo_TiempoTrafico</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>23208</td><td>39297</td><td>1.693252</td><td>1171.87</td><td>1084</td><td>ABOVE_AVERAGE</td><td>1.081061</td><td>50.494226</td><td>29.820851</td><td>[{'action_type': 'onsite_conversion.total_messaging_connection', 'value': '31'}, {'action_type': 'onsite_conversion.messaging_first_reply', 'value': '15'}, {'action_type': 'post_engagement', 'value': '11746'}, {'action_type': 'onsite_conversion.post_save', 'value': '3'}, {'action_type': 'comment', 'value': '6'}, {'action_type': 'page_engagement', 'value': '11747'}, {'action_type': 'onsite_conversion.messaging_user_depth_3_message_send', 'value': '8'}, {'action_type': 'post', 'value': '1'}, {'action_type': 'onsite_conversion.messaging_user_depth_2_message_send', 'value': '18'}, {'action_type': 'like', 'value': '1'}, {'action_type': 'onsite_conversion.messaging_conversation_started_7d', 'value': '23'}, {'action_type': 'video_view', 'value': '11539'}, {'action_type': 'post_reaction', 'value': '79'}, {'action_type': 'link_click', 'value': '118'}]</td><td>AVERAGE</td><td>AUCTION</td><td>118.0</td></tr><tr><td>120211236488470669</td><td>Test_AdVideo_AltaAmenidades</td><td>Test_Group_VideosGene ...

# %% [markdown]
# ### **expandir la columna {actions} crear columnas de cada seccion para su analisis**

# %%
#expandir a detalle columna actions y guardarla
import pandas as pd
import json

#cargar el csv guardado
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total.csv")

#Funcion para expandir columna actions
def expand_actions(actions):
    try:
        actions_list = json.loads(actions.replace("'", "\""))
        expanded = {action['action_type']: action['value'] for action in actions_list}
        return pd.Series(expanded)
    except Exception as e:
        print(f"Error al procesar la fila: {e}")
        return pd.Series()
    
#se aplica la funcion a la columna 'actions' y concatena los resultados
df_expanded = df['actions'].apply(expand_actions)

#concatenar las columnas nuevas con el Dataframe original
df_final = pd.concat([df.drop('actions', axis=1), df_expanded], axis=1)

#guardar el resultado en el CSV
df_final.to_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_expanded.csv", index=False)
print(df_final.columns)

#Revisar cambios
display(df_final)
print(df.columns)
# Out:
# Index(['ad_id', 'ad_name', 'adset_name', 'campaign_name', 'date_start',
#        'date_stop', 'reach', 'impressions', 'frequency', 'spend', 'clicks',
#        'conversion_rate_ranking', 'cpc', 'cpp', 'cpm', 'quality_ranking',
#        'buying_type', 'inline_link_clicks', 'post_engagement',
#        'page_engagement', 'video_view', 'post_reaction',
#        'onsite_conversion.total_messaging_connection',
#        'onsite_conversion.messaging_first_reply',
#        'onsite_conversion.post_save', 'comment',
#        'onsite_conversion.messaging_user_depth_3_message_send',
#        'onsite_conversion.messaging_user_depth_2_message_send',
#        'onsite_conversion.messaging_conversation_started_7d', 'link_click',
#        'post', 'like', 'onsite_conversion.messaging_welcome_message_view'],
#       dtype='object')
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ad_id</th><th>ad_name</th><th>adset_name</th><th>campaign_name</th><th>date_start</th><th>date_stop</th><th>reach</th><th>impressions</th><th>frequency</th><th>spend</th><th>clicks</th><th>conversion_rate_ranking</th><th>cpc</th><th>cpp</th><th>cpm</th><th>quality_ranking</th><th>buying_type</th><th>inline_link_clicks</th><th>post_engagement</th><th>page_engagement</th><th>video_view</th><th>post_reaction</th><th>onsite_conversion.total_messaging_connection</th><th>onsite_conversion.messaging_first_reply</th><th>onsite_conversion.post_save</th><th>comment</th><th>onsite_conversion.messaging_user_depth_3_message_send</th><th>onsite_conversion.messaging_user_depth_2_message_send</th><th>onsite_conversion.messaging_conversation_started_7d</th><th>link_click</th><th>post</th><th>like</th><th>onsite_conversion.messaging_welcome_message_view</th></tr></thead><tbody><tr><td>120211236488430669</td><td>Test_AdVideo_LosArtistas</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td
       'like', 'onsite_conversion.messaging_welcome_message_view']
#convertir cada columna a tipo numerico
for column in columns_to_convert:
    if column in df.columns:
        df[column] = pd.to_numeric(df[column], errors='coerce')
    else:
        print(f"Column {column} does not exist in DataFrame.")

#guardar el csv modificado
df.to_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_parametrosNumericos.csv", index=False)

#mostrar cambio
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ad_id</th><th>ad_name</th><th>adset_name</th><th>campaign_name</th><th>date_start</th><th>date_stop</th><th>reach</th><th>impressions</th><th>frequency</th><th>spend</th><th>clicks</th><th>conversion_rate_ranking</th><th>cpc</th><th>cpp</th><th>cpm</th><th>quality_ranking</th><th>buying_type</th><th>inline_link_clicks</th><th>post_engagement</th><th>page_engagement</th><th>video_view</th><th>post_reaction</th><th>onsite_conversion.total_messaging_connection</th><th>onsite_conversion.messaging_first_reply</th><th>onsite_conversion.post_save</th><th>comment</th><th>onsite_conversion.messaging_user_depth_3_message_send</th><th>onsite_conversion.messaging_user_depth_2_message_send</th><th>onsite_conversion.messaging_conversation_started_7d</th><th>link_click</th><th>post</th><th>like</th><th>onsite_conversion.messaging_welcome_message_view</th></tr></thead><tbody><tr><td>120211236488430669</td><td>Test_AdVideo_LosArtistas</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>436</td><td>622</td><td>1.426606</td><td>21.35</td><td>11</td><td>UNKNOWN</td><td>1.940909</td><td>48.96789</td><td>34.324759</td><td>UNKNOWN</td><td>AUCTION</td><td>null</td><td>106</td><td>106</td><td>105.0</td><td>1.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236578610669</td><td>Test_AdVideo_PreNavidad</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>205</td><td>347</td><td>1.692683</td><td>19.23</td><td>12</td><td>UNKNOWN</td><td>1.6025</td><td>93.804878</td><td>55.417867</td><td>UNKNOWN</td><td>AUCTION</td><td>null</td><td>48</td><td>48</td><td>48.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>4382</td><td>8530</td><td>1.9466</td><td>359.37</td><td>212</td><td>UNKNOWN</td><td>1.695142</td><td>82.010497</td><td>42.130129</td><td>UNKNOWN</td><td>AUCTION</td><td>20.0</td><td>1134</td><td>1134</td><td>1107.0</td><td>5.0</td><td>9.0</td><td>1.0</td><td>1.0</td><td>1.0</td><td>4.0</td><td>5.0</td><td>5.0</td><td>20.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488480669</td><td>Test_AdVideo_TiempoTrafico</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>23208</td><td>39297</td><td>1.693252</td><td>1171.87</td><td>1084</td><td>ABOVE_AVERAGE</td><td>1.081061</td><td>50.494226</td><td>29.820851</td><td>AVERAGE</td><td>AUCTION</td><td>118.0</td><td>11746</td><td>11747</td><td>11539.0</td><td>79.0</td><td>31.0</td><td>15.0</td><td>3.0</td><td>6.0</td><td>8.0</td><td>18.0</td><td>23.0</td><td>118.0</td><td>1.0</td><td>1.0</td><td>null</td></tr><tr><td>120211236488470669</td><td>Test_AdVideo_AltaAmenidades</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>5247</td><td>8702</td><td>1.658472</td><td>374.5</td><td>161</td><td>AVERAGE</td><td>2.326087</td><td>71.374119</td><td>43.036084</td><td>AVERAGE</td><td>AUCTION</td><td>35.0</td><td>1318</td><td>1318</td><td>1264.0</td><td>16.0</td><td>16.0</td><td>9.0</td><td>null</td><td>2.0</td><td>5.0</td><td>10.0</td><td>11.0</td><td>35.0</td><td>1.0</td><td>null</td><td>null</td></tr><tr><td>120211227579380669</td><td>Test_Ad_MoriMod146Mascotas</td><td>Test_Group_Mori_ABManualMejorado</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>7415</td><td>17335</td><td>2.337829</td><td>1120.44</td><td>390</td><td>UNKNOWN</td><td>2. ...

# %% [markdown]
# ## **cambiar columnas del english al spanish**

# %%
#cambiar columnas de csv con mas detalles en spanish
import pandas as pd

#leer el csv desde la ruta especificada
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_parametrosNumericos.csv")

#diccionario con los cambios de nombres en columnas/agregar nombres columnas a cambiar por nuevos nombres
new_column_names ={
    'ad_id': 'id_anuncio',
    'ad_name': 'nombre_anuncio',
    'adset_name':'grupo_anuncios',
    'campaign_name': 'nombre_campana',
    'date_start': 'fecha_inicio',
    'date_stop': 'fecha_finalizacion',
    'reach': 'personas_alcanzadas',
    'impressions': 'veces_mostrado',
    'frequency': 'promedio_frecuencia',
    'spend': 'gasto',
    'clicks': 'clicks_en_anuncio',
    'inline_link_clicks': 'click_enlace_trafico',
    'conversion_rate_ranking': 'conversion_mercado',
    'cpc': 'costo_por_click_anuncio',
    'cpp': 'costo_por_resultado',
    'cpm': 'costo_por_mil_impresiones',
    'quality_ranking': 'calidad_mercado',
    'buying_type': 'tipo_compra',
    'onsite_conversion.total_messaging_connection': 'conversion_boton_msj',
    'onsite_conversion.messaging_first_reply': 'conversion_primer_respuesta',
    'post_engagement': 'interaccion_post',
    'page_engagement': 'interaccion_page',
    'onsite_conversion.messaging_user_depth_2_message_send': '2do_msj_cliente',
    'onsite_conversion.messaging_conversation_started_7d': 'msj_iniciado_por_cliente_ultimos_7Dias',
    'video_view': 'vistas_video',
    'post_reaction': 'reacciones_post',
    'link_click': 'click_link',
    'post': 'contenido_publicado',
    'onsite_conversion.post_save': 'contenido_guardado',
    'comment': 'comentarios',
    'onsite_conversion.messaging_user_depth_3_message_send': '3er_msj_cliente',
    'like': 'like',
    'onsite_conversion.messaging_welcome_message_view': 'vistas_mensaje_bienvenida',
    'onsite_conversion.messaging_conversation_replied_7d': 'msjs_respondidos_por_pecsa_antes_de_7Dias',
    'onsite_conversion.messaging_user_depth_5_message_send': '5to_msj_cliente'
    # Agrega todos los nombres de columnas que deseas cambiar
    
}

# Renombrar las columnas
df.rename(columns=new_column_names, inplace=True)

# Guardar el DataFrame renombrado en un nuevo archivo CSV
df.to_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_spanish.csv", index=False)

print("Archivo renombrado y guardado exitosamente.")
display(df)
# Out:
# Archivo renombrado y guardado exitosamente.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_anuncio</th><th>nombre_anuncio</th><th>grupo_anuncios</th><th>nombre_campana</th><th>fecha_inicio</th><th>fecha_finalizacion</th><th>personas_alcanzadas</th><th>veces_mostrado</th><th>promedio_frecuencia</th><th>gasto</th><th>clicks_en_anuncio</th><th>conversion_mercado</th><th>costo_por_click_anuncio</th><th>costo_por_resultado</th><th>costo_por_mil_impresiones</th><th>calidad_mercado</th><th>tipo_compra</th><th>click_enlace_trafico</th><th>interaccion_post</th><th>interaccion_page</th><th>vistas_video</th><th>reacciones_post</th><th>conversion_boton_msj</th><th>conversion_primer_respuesta</th><th>contenido_guardado</th><th>comentarios</th><th>3er_msj_cliente</th><th>2do_msj_cliente</th><th>msj_iniciado_por_cliente_ultimos_7Dias</th><th>click_link</th><th>contenido_publicado</th><th>like</th><th>vistas_mensaje_bienvenida</th></tr></thead><tbody><tr><td>120211236488430669</td><td>Test_AdVideo_LosArtistas</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>436</td><td>622</td><td>1.426606</td><td>21.35</td><td>11</td><td>UNKNOWN</td><td>1.940909</td><td>48.96789</td><td>34.324759</td><td>UNKNOWN</td><td>AUCTION</td><td>null</td><td>106</td><td>106</td><td>105.0</td><td>1.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236578610669</td><td>Test_AdVideo_PreNavidad</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>205</td><td>347</td><td>1.692683</td><td>19.23</td><td>12</td><td>UNKNOWN</td><td>1.6025</td><td>93.804878</td><td>55.417867</td><td>UNKNOWN</td><td>AUCTION</td><td>null</td><td>48</td><td>48</td><td>48.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>4382</td><td>8530</td><td>1.9466</td><td>359.37</td><td>212</td><td>UNKNOWN</td><td>1.695142</td><td>82.010497</td><td>42.130129</td><td>UNKNOWN</td><td>AUCTION</td><td>20.0</td><td>1134</td><td>1134</td><td>1107.0</td><td>5.0</td><td>9.0</td><td>1.0</td><td>1.0</td><td>1.0</td><td>4.0</td><td>5.0</td><td>5.0</td><td>20.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488480669</td><td>Test_AdVideo_TiempoTrafico</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>23208</td><td>39297</td><td>1.693252</td><td>1171.87</td><td>1084</td><td>ABOVE_AVERAGE</td><td>1.081061</td><td>50.494226</td><td>29.820851</td><td>AVERAGE</td><td>AUCTION</td><td>118.0</td><td>11746</td><td>11747</td><td>11539.0</td><td>79.0</td><td>31.0</td><td>15.0</td><td>3.0</td><td>6.0</td><td>8.0</td><td>18.0</td><td>23.0</td><td>118.0</td><td>1.0</td><td>1.0</td><td>null</td></tr><tr><td>120211236488470669</td><td>Test_AdVideo_AltaAmenidades</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>5247</td><td>8702</td><td>1.658472</td><td>374.5</td><td>161</td><td>AVERAGE</td><td>2.326087</td><td>71.374119</td><td>43.036084</td><td>AVERAGE</td><td>AUCTION</td><td>35.0</td><td>1318</td><td>1318</td><td>1264.0</td><td>16.0</td><td>16.0</td><td>9.0</td><td>null</td><td>2.0</td><td>5.0</td><td>10.0</td><td>11.0</td><td>35.0</td><td>1.0</td><td>null</td><td>null</td></tr><tr><td>120211227579380669</td><td>Test_Ad_MoriMod146Mascotas</td><td>Test_Group_Mori_ABManualMejorado</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>7415</td><td>17335</td><td>2.337829</td><td>1120.44</td><td>390</td><td>UNKNOWN</td><td>2.872923</td> ...

# %% [markdown]
# ## **Cambiar el idioma de las columnas de english a spanish**

# %%
#cambiar el contenido de las columnas de spanish a english
import pandas as pd

#cargar el archivo csv de origen en un dataframe
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_spanish.csv")

#listar las columnas que vamos a remplazar
columns_to_replace=['tipo_compra','conversion_mercado','calidad_mercado']

#diccionario con los valores a remplazar y los nuevos valores
replacements = {
    'UNKNOWN': 'desconocido',
    'ABOVE_AVERAGE': 'arriba del promedio',
    'AVERAGE': 'promedio',
    'BELOW_AVERAGE_35': 'abajo del promedio',
    'BELOW_AVERAGE_20': 'abajo del promedio',
    'AUCTION':'subasta'

}

#remplazamos valores 'UNKNOWN' por 'desconocido'
df[columns_to_replace]=df[columns_to_replace].replace(replacements)

#guardar el dataframe en un nuevo archivo csv
df.to_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv", index=False)
print("Archivo renombrado y guardado exitosamente.")
display(df)
# Out:
# Archivo renombrado y guardado exitosamente.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id
td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>7415</td><td>17335</td><td>2.337829</td><td>1120.44</td><td>390</td> ...

# %%
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_anuncio</th><th>nombre_anuncio</th><th>grupo_anuncios</th><th>nombre_campana</th><th>fecha_inicio</th><th>fecha_finalizacion</th><th>personas_alcanzadas</th><th>veces_mostrado</th><th>promedio_frecuencia</th><th>gasto</th><th>clicks_en_anuncio</th><th>conversion_mercado</th><th>costo_por_click_anuncio</th><th>costo_por_resultado</th><th>costo_por_mil_impresiones</th><th>calidad_mercado</th><th>tipo_compra</th><th>click_enlace_trafico</th><th>interaccion_post</th><th>interaccion_page</th><th>vistas_video</th><th>reacciones_post</th><th>conversion_boton_msj</th><th>conversion_primer_respuesta</th><th>contenido_guardado</th><th>comentarios</th><th>3er_msj_cliente</th><th>2do_msj_cliente</th><th>msj_iniciado_por_cliente_ultimos_7Dias</th><th>click_link</th><th>contenido_publicado</th><th>like</th><th>vistas_mensaje_bienvenida</th></tr></thead><tbody><tr><td>120211236488430669</td><td>Test_AdVideo_LosArtistas</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>436</td><td>622</td><td>1.426606</td><td>21.35</td><td>11</td><td>desconocido</td><td>1.940909</td><td>48.96789</td><td>34.324759</td><td>desconocido</td><td>subasta</td><td>null</td><td>106</td><td>106</td><td>105.0</td><td>1.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236578610669</td><td>Test_AdVideo_PreNavidad</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>205</td><td>347</td><td>1.692683</td><td>19.23</td><td>12</td><td>desconocido</td><td>1.6025</td><td>93.804878</td><td>55.417867</td><td>desconocido</td><td>subasta</td><td>null</td><td>48</td><td>48</td><td>48.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488410669</td><td>Test_AdVideo_PrivEncinosNewLot</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>4382</td><td>8530</td><td>1.9466</td><td>359.37</td><td>212</td><td>desconocido</td><td>1.695142</td><td>82.010497</td><td>42.130129</td><td>desconocido</td><td>subasta</td><td>20.0</td><td>1134</td><td>1134</td><td>1107.0</td><td>5.0</td><td>9.0</td><td>1.0</td><td>1.0</td><td>1.0</td><td>4.0</td><td>5.0</td><td>5.0</td><td>20.0</td><td>null</td><td>null</td><td>null</td></tr><tr><td>120211236488480669</td><td>Test_AdVideo_TiempoTrafico</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>23208</td><td>39297</td><td>1.693252</td><td>1171.87</td><td>1084</td><td>arriba del promedio</td><td>1.081061</td><td>50.494226</td><td>29.820851</td><td>promedio</td><td>subasta</td><td>118.0</td><td>11746</td><td>11747</td><td>11539.0</td><td>79.0</td><td>31.0</td><td>15.0</td><td>3.0</td><td>6.0</td><td>8.0</td><td>18.0</td><td>23.0</td><td>118.0</td><td>1.0</td><td>1.0</td><td>null</td></tr><tr><td>120211236488470669</td><td>Test_AdVideo_AltaAmenidades</td><td>Test_Group_VideosGeneralesPt2</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>5247</td><td>8702</td><td>1.658472</td><td>374.5</td><td>161</td><td>promedio</td><td>2.326087</td><td>71.374119</td><td>43.036084</td><td>promedio</td><td>subasta</td><td>35.0</td><td>1318</td><td>1318</td><td>1264.0</td><td>16.0</td><td>16.0</td><td>9.0</td><td>null</td><td>2.0</td><td>5.0</td><td>10.0</td><td>11.0</td><td>35.0</td><td>1.0</td><td>null</td><td>null</td></tr><tr><td>120211227579380669</td><td>Test_Ad_MoriMod146Mascotas</td><td>Test_Group_Mori_ABManualMejorado</td><td>Test_All_Nov_Camp</td><td>2024-10-12</td><td>2024-11-10</td><td>7415</td><td>17335</td><td>2.337829</td><td>1120.44</td><td>390</td> ...
