# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "click_enlace_trafico"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con menor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de click_enlace_trafico
#                 nombre_anuncio  click_enlace_trafico
#       Test_AdVideo_LosArtistas                   0.0
#        Test_AdVideo_PreNavidad                   0.0
#    Test_Ad_AltaMod106_ABManual                   5.0
#  Test_Ad_AltaMod88Fam_ABManual                   6.0
# Test_AdVideo_PrivEncinosNewLot                  20.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "click_link"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con menor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de click_link
#                 nombre_anuncio  click_link
#       Test_AdVideo_LosArtistas         0.0
#        Test_AdVideo_PreNavidad         0.0
#    Test_Ad_AltaMod106_ABManual         5.0
#  Test_Ad_AltaMod88Fam_ABManual         6.0
# Test_AdVideo_PrivEncinosNewLot        20.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "clicks_en_anuncio"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con menor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de clicks_en_anuncio
#                nombre_anuncio  clicks_en_anuncio
#      Test_AdVideo_LosArtistas                 11
#       Test_AdVideo_PreNavidad                 12
# Test_Ad_AltaMod88Fam_ABManual                 19
#   Test_Ad_AltaMod106_ABManual                 21
#   Test_Ad_MoriMod146Seguridad                110

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "comentarios"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con menor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de comentarios
#               nombre_anuncio  comentarios
#  Test_AdAguilando_Encinos146          0.0
#     Test_AdVideo_LosArtistas          0.0
#      Test_AdVideo_PreNavidad          0.0
# Test_Ad_Aguinaldo_Encinos106          0.0
#  Test_Ad_AltaMod106_ABManual          0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "conversion_boton_msj"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con menor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de conversion_boton_msj
#                nombre_anuncio  conversion_boton_msj
#      Test_AdVideo_LosArtistas                   0.0
#       Test_AdVideo_PreNavidad                   0.0
#   Test_Ad_AltaMod106_ABManual                   1.0
# Test_Ad_AltaMod88Fam_ABManual                   2.0
#    Test_Ad_MoriMod106Momentos                   4.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "costo_por_click_anuncio"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con menor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de costo_por_click_anuncio
#                 nombre_anuncio  costo_por_click_anuncio
#     Test_AdVideo_TiempoTrafico                 1.081061
#    Test_AdAguilando_Encinos146                 1.241005
#        Test_AdVideo_PreNavidad                 1.602500
# Test_AdVideo_PrivEncinosNewLot                 1.695142
#   Test_Ad_Aguinaldo_Encinos106                 1.706832

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "costo_por_mil_impresiones"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de costo_por_mil_impresiones
#              nombre_anuncio  costo_por_mil_impresiones
#  Test_AdVideo_TiempoTrafico                  29.820851
#  Test_Ad_Mori_CorreleMod106                  32.794766
#    Test_AdVideo_LosArtistas                  34.324759
# Test_Ad_AltaMod106_ABManual                  37.295222
#  Test_Ad_Mori_CorreleMod146                  40.729092

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "costo_por_resultado"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de costo_por_resultado
#              nombre_anuncio  costo_por_resultado
#    Test_AdVideo_LosArtistas            48.967890
#  Test_AdVideo_TiempoTrafico            50.494226
# Test_Ad_AltaMod106_ABManual            52.853688
#  Test_Ad_Mori_CorreleMod106            57.165588
# Test_AdVideo_AltaAmenidades            71.374119

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "gasto"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de gasto
#                nombre_anuncio  gasto
#       Test_AdVideo_PreNavidad  19.23
#      Test_AdVideo_LosArtistas  21.35
#   Test_Ad_AltaMod106_ABManual  43.71
# Test_Ad_AltaMod88Fam_ABManual  59.49
#   Test_AdAguilando_Encinos146 246.96

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "interaccion_post"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con pero numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de interaccion_post
#                nombre_anuncio  interaccion_post
#   Test_Ad_AltaMod106_ABManual                 6
# Test_Ad_AltaMod88Fam_ABManual                11
#   Test_Ad_MoriMod146Seguridad                30
#   Test_AdAguilando_Encinos146                45
#       Test_AdVideo_PreNavidad                48

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "like"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de like
#                 nombre_anuncio  like
#    Test_AdVideo_AltaAmenidades   0.0
#       Test_AdVideo_LosArtistas   0.0
#        Test_AdVideo_PreNavidad   0.0
# Test_AdVideo_PrivEncinosNewLot   0.0
#    Test_Ad_AltaMod106_ABManual   0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "personas_alcanzadas"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de personas_alcanzadas
#                nombre_anuncio  personas_alcanzadas
#       Test_AdVideo_PreNavidad                  205
# Test_Ad_AltaMod88Fam_ABManual                  428
#      Test_AdVideo_LosArtistas                  436
#   Test_Ad_AltaMod106_ABManual                  827
#   Test_Ad_MoriMod146Seguridad                 2327

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "promedio_frecuencia"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de promedio_frecuencia
#              nombre_anuncio  promedio_frecuencia
# Test_Ad_AltaMod106_ABManual             1.417171
#    Test_AdVideo_LosArtistas             1.426606
# Test_AdAguilando_Encinos146             1.617953
# Test_AdVideo_AltaAmenidades             1.658472
#     Test_AdVideo_PreNavidad             1.692683

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "reacciones_post"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de reacciones_post
#              nombre_anuncio  reacciones_post
#     Test_AdVideo_PreNavidad              0.0
# Test_Ad_MoriMod146Seguridad              0.0
# Test_AdAguilando_Encinos146              1.0
#    Test_AdVideo_LosArtistas              1.0
# Test_Ad_AltaMod106_ABManual              1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "veces_mostrado"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de veces_mostrado
#                nombre_anuncio  veces_mostrado
#       Test_AdVideo_PreNavidad             347
#      Test_AdVideo_LosArtistas             622
# Test_Ad_AltaMod88Fam_ABManual             771
#   Test_Ad_AltaMod106_ABManual            1172
#   Test_Ad_MoriMod146Seguridad            4355

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "vistas_video"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de vistas_video
#                   nombre_anuncio  vistas_video
#      Test_AdAguilando_Encinos146           0.0
#     Test_Ad_Aguinaldo_Encinos106           0.0
#      Test_Ad_AltaMod106_ABManual           0.0
#       Test_Ad_AltaMod80_ABManual           0.0
# Test_Ad_AltaMod88Seguri_ABManual           0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "contenido_guardado"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de contenido_guardado
#               nombre_anuncio  contenido_guardado
#  Test_AdAguilando_Encinos146                 0.0
#  Test_AdVideo_AltaAmenidades                 0.0
#     Test_AdVideo_LosArtistas                 0.0
#      Test_AdVideo_PreNavidad                 0.0
# Test_Ad_Aguinaldo_Encinos106                 0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "conversion_primer_respuesta"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con peor numero
top_5_ads = df_grouped.nsmallest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top5ads_df = top_5_ads.reset_index()
top5ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Menor Número de", variable_analizar)
print(top5ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Peor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Menor Número de conversion_primer_respuesta
#                 nombre_anuncio  conversion_primer_respuesta
#       Test_AdVideo_LosArtistas                          0.0
#        Test_AdVideo_PreNavidad                          0.0
#  Test_Ad_AltaMod88Fam_ABManual                          0.0
# Test_AdVideo_PrivEncinosNewLot                          1.0
#    Test_Ad_AltaMod106_ABManual                          1.0
