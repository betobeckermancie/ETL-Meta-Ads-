# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "click_enlace_trafico"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos el gráfico de barras
plt.figure(figsize=(10, 6))
top_5_ads_df.plot(kind='bar', x='nombre_anuncio', y=variable_analizar, color="#FF6262", legend=False)

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de click_enlace_trafico
#               nombre_anuncio  click_enlace_trafico
# Test_Ad_Aguinaldo_Encinos106                 203.0
#   Test_Ad_Mori_CorreleMod146                 119.0
#   Test_AdVideo_TiempoTrafico                 118.0
#   Test_Ad_AltaMod80_ABManual                 113.0
#   Test_Ad_Mori_CorreleMod106                 104.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "click_link"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de click_link
#               nombre_anuncio  click_link
# Test_Ad_Aguinaldo_Encinos106       203.0
#   Test_Ad_Mori_CorreleMod146       119.0
#   Test_AdVideo_TiempoTrafico       118.0
#   Test_Ad_AltaMod80_ABManual       113.0
#   Test_Ad_Mori_CorreleMod106       104.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "clicks_en_anuncio"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de clicks_en_anuncio
#               nombre_anuncio  clicks_en_anuncio
#   Test_AdVideo_TiempoTrafico               1084
# Test_Ad_Aguinaldo_Encinos106                666
#   Test_Ad_AltaMod80_ABManual                505
#   Test_Ad_Mori_CorreleMod106                394
#   Test_Ad_MoriMod146Mascotas                390

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "comentarios"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de comentarios
#                   nombre_anuncio  comentarios
#       Test_AdVideo_TiempoTrafico          6.0
#      Test_AdVideo_AltaAmenidades          2.0
#   Test_AdVideo_PrivEncinosNewLot          1.0
#       Test_Ad_AltaMod80_ABManual          1.0
# Test_Ad_AltaMod88Seguri_ABManual          1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "conversion_boton_msj"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de conversion_boton_msj
#                   nombre_anuncio  conversion_boton_msj
#       Test_AdVideo_TiempoTrafico                  31.0
#     Test_Ad_Aguinaldo_Encinos106                  30.0
#       Test_Ad_AltaMod80_ABManual                  23.0
#       Test_Ad_MoriMod146Mascotas                  18.0
# Test_Ad_AltaMod88Seguri_ABManual                  17.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "costo_por_click_anuncio"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de costo_por_click_anuncio
#                nombre_anuncio  costo_por_click_anuncio
#    Test_Ad_Mori_CorreleMod146                 4.031916
#    Test_Ad_MoriMod106Momentos                 3.160305
# Test_Ad_AltaMod88Fam_ABManual                 3.131053
#   Test_Ad_MoriMod146Seguridad                 3.049727
#    Test_Ad_MoriMod146Mascotas                 2.872923

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "costo_por_mil_impresiones"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de costo_por_mil_impresiones
#                   nombre_anuncio  costo_por_mil_impresiones
#    Test_Ad_AltaMod88Fam_ABManual                  77.159533
#      Test_Ad_MoriMod146Seguridad                  77.030999
#       Test_Ad_AltaMod80_ABManual                  64.877040
#       Test_Ad_MoriMod146Mascotas                  64.634554
# Test_Ad_AltaMod88Seguri_ABManual                  61.202250

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "costo_por_resultado"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de costo_por_resultado
#                   nombre_anuncio  costo_por_resultado
#       Test_Ad_MoriMod146Mascotas           151.104518
#       Test_Ad_AltaMod80_ABManual           149.983863
#      Test_Ad_MoriMod146Seguridad           144.164160
#    Test_Ad_AltaMod88Fam_ABManual           138.995327
# Test_Ad_AltaMod88Seguri_ABManual           122.280318

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "gasto"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de gasto
#               nombre_anuncio   gasto
#   Test_Ad_Mori_CorreleMod146 1241.83
#   Test_Ad_AltaMod80_ABManual 1208.27
#   Test_AdVideo_TiempoTrafico 1171.87
# Test_Ad_Aguinaldo_Encinos106 1136.75
#   Test_Ad_MoriMod146Mascotas 1120.44

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "interaccion_post"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de interaccion_post
#                 nombre_anuncio  interaccion_post
#     Test_AdVideo_TiempoTrafico             11746
#    Test_AdVideo_AltaAmenidades              1318
# Test_AdVideo_PrivEncinosNewLot              1134
#   Test_Ad_Aguinaldo_Encinos106               214
#     Test_Ad_Mori_CorreleMod146               128

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "like"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de like
#                   nombre_anuncio  like
#       Test_Ad_Mori_CorreleMod106   3.0
#     Test_Ad_Aguinaldo_Encinos106   2.0
# Test_Ad_AltaMod88Seguri_ABManual   2.0
#       Test_Ad_Mori_CorreleMod146   2.0
#      Test_AdAguilando_Encinos146   1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "personas_alcanzadas"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de personas_alcanzadas
#               nombre_anuncio  personas_alcanzadas
#   Test_AdVideo_TiempoTrafico                23208
#   Test_Ad_Mori_CorreleMod106                18854
#   Test_Ad_Mori_CorreleMod146                16041
# Test_Ad_Aguinaldo_Encinos106                11605
#   Test_Ad_AltaMod80_ABManual                 8056

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "promedio_frecuencia"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de promedio_frecuencia
#                   nombre_anuncio  promedio_frecuencia
#       Test_Ad_MoriMod146Mascotas             2.337829
#       Test_Ad_AltaMod80_ABManual             2.311817
#       Test_Ad_MoriMod106Momentos             2.183173
# Test_Ad_AltaMod88Seguri_ABManual             1.997971
#   Test_AdVideo_PrivEncinosNewLot             1.946600

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "reacciones_post"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de reacciones_post
#               nombre_anuncio  reacciones_post
#   Test_AdVideo_TiempoTrafico             79.0
#  Test_AdVideo_AltaAmenidades             16.0
# Test_Ad_Aguinaldo_Encinos106             10.0
#   Test_Ad_Mori_CorreleMod106              8.0
#   Test_Ad_Mori_CorreleMod146              8.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "veces_mostrado"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de veces_mostrado
#               nombre_anuncio  veces_mostrado
#   Test_AdVideo_TiempoTrafico           39297
#   Test_Ad_Mori_CorreleMod106           32865
#   Test_Ad_Mori_CorreleMod146           30490
# Test_Ad_Aguinaldo_Encinos106           21720
#   Test_Ad_AltaMod80_ABManual           18624

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "vistas_video"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de vistas_video
#                 nombre_anuncio  vistas_video
#     Test_AdVideo_TiempoTrafico       11539.0
#    Test_AdVideo_AltaAmenidades        1264.0
# Test_AdVideo_PrivEncinosNewLot        1107.0
#       Test_AdVideo_LosArtistas         105.0
#        Test_AdVideo_PreNavidad          48.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "contenido_guardado"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de contenido_guardado
#                   nombre_anuncio  contenido_guardado
#       Test_AdVideo_TiempoTrafico                 3.0
#   Test_AdVideo_PrivEncinosNewLot                 1.0
# Test_Ad_AltaMod88Seguri_ABManual                 1.0
#      Test_AdAguilando_Encinos146                 0.0
#      Test_AdVideo_AltaAmenidades                 0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargamos el csv
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Total/anuncios_insights_general_total_limpiado.csv")

# varible para analizar/se cambia 
variable_analizar = "conversion_primer_respuesta"

# se agrupa por el nombre del anuncio para que no se repita
df_grouped = df.groupby('nombre_anuncio')[variable_analizar].sum()

#ordena la variable y obtiene los 5 con mayor numero
top_5_ads = df_grouped.nlargest(5)

# Convertimos el resultado en un DataFrame para un formato de tabla
top_5_ads_df = top_5_ads.reset_index()
top_5_ads_df.columns = ["nombre_anuncio", variable_analizar]

# Imprimimos en pantalla el top 5 con nombre y cantidad en formato tabla
print("Top 5 Anuncios con Mayor Número de", variable_analizar)
print(top_5_ads_df.to_string(index=False))

# Creamos grafico de barras
plt.figure(figsize=(10, 6))
top_5_ads.plot(kind='bar', color="#FF6262")

# etiquetas y titulo a las graficas
plt.title(f"Top 5 Anuncios con Mayor Número de {variable_analizar}", fontsize=16)
plt.xlabel('Nombre de Anuncio',fontsize=12)
plt.ylabel(f"{variable_analizar}", fontsize=12)
plt.xticks(rotation=45, ha="right")

# mostramos el grafico
plt.tight_layout()
plt.show()
# Out:
# Top 5 Anuncios con Mayor Número de conversion_primer_respuesta
#               nombre_anuncio  conversion_primer_respuesta
# Test_Ad_Aguinaldo_Encinos106                         18.0
#   Test_AdVideo_TiempoTrafico                         15.0
#   Test_Ad_AltaMod80_ABManual                         15.0
#   Test_Ad_Mori_CorreleMod106                         13.0
#   Test_Ad_MoriMod146Mascotas                         11.0
