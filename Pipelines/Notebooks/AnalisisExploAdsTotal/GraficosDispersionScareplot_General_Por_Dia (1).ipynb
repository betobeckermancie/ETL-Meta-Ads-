# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#cargar el csv en un dataframe
df = pd.read_csv("/dbfs/mnt/processed/Ads_General_Por_Dia/anuncios_insights_general_por_dia_limpiado.csv")

#filtrar solo las columnas numericas
numeric_columns = df.select_dtypes(include='number').columns

#Iterar sobre todas las columnas numericas y crear scatterplots para compararlas con el gasto
for column in numeric_columns:
    if column != "gasto": #ignorar la columna 'gasto'
        plt.figure(figsize=(8,6))
        sns.scatterplot(x=column, y="gasto", data=df, color="blue")

        #agregar etiquetas y titulos 
        plt.title (f'Scatterplor de {column} vs Gasto')
        plt.xlabel(column)
        plt.ylabel('Gasto($)')

        #mostrar el grafico
        plt.show()
print(df.columns)
# Out:
# Index(['id_anuncio', 'nombre_anuncio', 'adset_name', 'nombre_campana',
#        'fecha_inicio', 'fecha_finalizacion', 'personas_alcanzadas',
#        'veces_mostrado', 'promedio_frecuencia', 'gasto', 'clicks_en_anuncio',
#        'click_enlace_trafico', 'conversion_mercado', 'costo_por_click_anuncio',
#        'costo_por_resultado', 'costo_por_mil_impresiones', 'calidad_mercado',
#        'tipo_compra', 'interaccion_post', 'interaccion_page', 'click_link',
#        'conversion_boton_msj', 'conversion_primer_respuesta',
#        '3er_msj_cliente', '2do_msj_cliente', 'like',
#        'msj_iniciado_por_cliente_ultimos_7Dias', 'reacciones_post',
#        'comentarios', 'contenido_publicado', 'vistas_video',
#        'contenido_guardado', 'vistas_mensaje_bienvenida',
#        'msjs_respondidos_por_pecsa_antes_de_7Dias', '5to_msj_cliente'],
#       dtype='object')
